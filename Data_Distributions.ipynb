# %% [markdown]
# Choose 6 distributions from the list of random distributions available in NumPy, called "Distributions".
#
# For each distribution:
#
#     Generate a random variable with 100 datapoints using the code distributionvar = np.random.distributionname([arguments], 100), replacing distributionvar with an appropriate variable name and distributionname with the name of the distribution you’ve chosen, and filling in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, go back to the “Other Distributions” assignment for examples of code to use as a starting point.
#
#     Graph the variable using a histogram.
#
#     Compute the mean and standard deviation and plot them as vertical lines on the histogram.
#
#     Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics of the distributions that could be usefully described using the mean and/or standard deviation?

# %% [markdown]
# Statistics provided information as to whether the variable was normally distributed or not. Common characteristics that could be usefully described,
# or at least identified, include skewness and kurtosis.

# %%
# All imports here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Distribution 1 = Normal (normal([loc, scale, size]))
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
normal_var = np.random.normal(5, 40, 100)

# Graphed the variable using a histogram
plt.hist(normal_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(normal_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(normal_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(normal_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %%
# Distribution 2 = Exponential([scale, size])
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
exponential_var = np.random.exponential(40, 100)

# Graphed the variable using a histogram
plt.hist(exponential_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(exponential_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(exponential_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(exponential_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %%
# Distribution 3 = logistic([loc, scale, size])
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
logistic_var = np.random.logistic(5, 40, 100)

# Graphed the variable using a histogram
plt.hist(logistic_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(logistic_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(logistic_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(logistic_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %%
# Distribution 4 = gumbel([loc, scale, size])
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
gumbel_var = np.random.gumbel(5, 40, 100)

# Graphed the variable using a histogram
plt.hist(gumbel_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(gumbel_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(gumbel_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(gumbel_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %%
# Distribution 5 = hypergeometric(ngood, nbad, nsample[, size])
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
hypergeometric_var = np.random.hypergeometric(50, 40, 65, 100)

# Graphed the variable using a histogram
plt.hist(hypergeometric_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(hypergeometric_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(hypergeometric_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(hypergeometric_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %%
# Distribution 6 = laplace([loc, scale, size])
# Generate a random variable with 100 datapoints using the code 
# distributionvar = np.random.distributionname([arguments], 100), 
# replacing distributionvar with an appropriate variable name and 
# distributionname with the name of the distribution you’ve chosen, 
# and filling in the empty space in the parentheses with your chosen values 
# for the appropriate parameters. 
 
laplace_var = np.random.laplace(50, 65, 100)

# Graphed the variable using a histogram
plt.hist(laplace_var, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(laplace_var.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(laplace_var.mean() + normal_var.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(laplace_var.mean()-normal_var.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %% [markdown]
# Additionally:
#
#     Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and a standard deviation of 1.
#
#     Add them together to create a third variable.
#
#     Graph the third variable using a histogram.
#
#     Compute the mean and standard deviation and plot them as vertical lines on the histogram.
#
#     Evaluate the descriptive statistics against the data.

# %%
# Generated two normally-distributed variables as instructed
norm_var_1 = np.random.normal(5, 0.5, 100)
norm_var_2 = np.random.normal(10, 1, 100)

# Added them together in new variable
norm_var_3 = norm_var_1 + norm_var_2

# Plotted the new variable
plt.hist(norm_var_3, bins=50, color='r')

# Computed the mean and standard deviation and plot them as vertical lines 
# on the histogram.
# Added a vertical line at the mean.
plt.axvline(norm_var_3.mean(), color='b', linestyle='solid', linewidth=3)

# Added a vertical line at one standard deviation above the mean.
plt.axvline(norm_var_3.mean() + norm_var_3.std(), color='b', linestyle='dashed', linewidth=2)

# Added a vertical line at one standard deviation below the mean.
plt.axvline(norm_var_3.mean()-norm_var_3.std(), color='b', linestyle='dashed', linewidth=2) 

# Printed the histogram.
plt.show()

# %% [markdown]
# Evaluate the descriptive statistics against the data.
#
# Normal distribution with the mean at 15, one stdv above at 16 and one stdv below
# at 14. Data ranges from 12-18.
